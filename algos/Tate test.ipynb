# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import os
import PIL
import PIL.Image
import pathlib
import math
import copy

# %% [markdown]
# ## Preprocessing

# %%
 def downscale_images(images, scale=30):
    """
    Downscales images in an array.
    Args:
        images: array of images to be downscaled 
        scale: 

    Returns: array of downscaled down images

    """
    resized = []
    
    for img in images:
        
        width = int(img.shape[1] * scale / 100)
        height = int(img.shape[0] * scale / 100)
        dim = (width, height)

        resized.append(cv2.resize(img, dim, interpolation = cv2.INTER_AREA))
    
    return resized

# %%
def load_and_preprocess(path):
    
    
    # directory with the images
    data_dir = pathlib.Path(path)
    
    
    # how many images are in the directory
    image_count = len(list(data_dir.glob('*')))
    print(f"Number of images found in {path}: {image_count}")


    paintings_path = list(data_dir.glob('*'))
    paintings_path = [str(path) for path in paintings_path]
    
    # sort by img number
    paintings_path = sorted(paintings_path, key=lambda path: int(path.split('_')[-1].split('.')[0]))
    
    
    # loading images, in BGR
    paintings = [cv2.imread(painting_path) for painting_path in paintings_path]
    paintings = downscale_images(paintings)
    
    
    # converting to gray
    paintings_gray = [cv2.cvtColor(painting, cv2.COLOR_BGR2GRAY) for painting in paintings]
    
    # converting to RGB for later visualisation
    paintings_rgb = [cv2.cvtColor(painting, cv2.COLOR_BGR2RGB) for painting in paintings]
    
    painting_tuple = (paintings_gray, paintings_rgb)
    
    return painting_tuple

# %% [markdown]
# ## Loading stolen paintings

# %%
stolen_art_dir_path = "../datasets/Tate-500-wop-opac/"
stolen_paintings = load_and_preprocess(stolen_art_dir_path)
# Out:
# Number of images found in ../datasets/Tate-500-wop-opac/: 477

# %% [markdown]
# ## Loading found paintings
# Paintings which I want to test against the stolen images.

# %%
found_paintings_dir_path = "../augmentation/Tate-500-wop-opac_aug/" 
found_paintings = load_and_preprocess(found_paintings_dir_path)
# Out:
# Number of images found in ../augmentation/Tate-500-wop-opac_aug/: 477

# %%
def display_compared(img1, img2):
    # Display traning image and testing image
    fx, plots = plt.subplots(1, 2, figsize=(20,10))

    plots[0].set_title("Stolen Image")
    plots[0].imshow(img1)

    plots[1].set_title("Comparing to")
    plots[1].imshow(img2)

# %% [markdown]
# ## Scaling functions for visualisation
#
# Functions mainly for downscaling the paintings/keypoints before visualisation. Greatly reduces the size of the notebook.

# %%
def features_deepcopy (f):
    return [cv2.KeyPoint(x = k.pt[0], y = k.pt[1], 
            _size = k.size, _angle = k.angle, 
            _response = k.response, _octave = k.octave, 
            _class_id = k.class_id) for k in f]

# %%
def scale_keypoints(keypoints, scale):
    
    for keypoint in keypoints:
        new_x = math.trunc(keypoint.pt[0]*(scale/100) )
        new_y = math.trunc(keypoint.pt[1]*(scale/100) )
        keypoint_scaled = (new_x, new_y) 
        keypoint.pt = keypoint_scaled

# %%
def draw_matches_scaled(found_painting, found_painting_keypoints,
                        stolen_painting, stolen_painting_keypoints,
                        matches, matchesMask, draw_params, scale = 20):
    
    # scale the paintings
    found_painting = downscale_images([found_painting], scale)[0]
    stolen_painting = downscale_images([stolen_painting], scale)[0]
    
    found_painting_keypoints_scaled = features_deepcopy(found_painting_keypoints)
    scale_keypoints(found_painting_keypoints_scaled, scale)
    
    stolen_painting_keypoints_scaled = features_deepcopy(stolen_painting_keypoints)
    scale_keypoints(stolen_painting_keypoints_scaled, scale)

    result = cv2.drawMatchesKnn(found_painting, found_painting_keypoints_scaled,
                                stolen_painting, stolen_painting_keypoints_scaled,
                                matches, None, **draw_params)
    
    return result

# %% [markdown]
# # ORB

# %%
# Creating an ORB object
orb = cv2.ORB_create(nfeatures=500)

# %%
def visualize_keypoints(image, keypoints, scale = 100):
    
    # SCALE HAS TO BE 100, TODO
    
    keypoints_without_size = np.copy(image)
    keypoints_with_size = np.copy(image)

    keypoints_without_size = downscale_images([keypoints_without_size], scale)[0]
    keypoints_with_size = downscale_images([keypoints_with_size], scale)[0]
    
    keypoints_scaled = features_deepcopy(keypoints)
    scale_keypoints(keypoints_scaled, scale)
    
    cv2.drawKeypoints(image, keypoints_scaled, keypoints_without_size, color = (0, 255, 0))

    cv2.drawKeypoints(image, keypoints_scaled, keypoints_with_size, flags = cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    
    # Display image with and without keypoints size
    fx, plots = plt.subplots(1, 2, figsize=(20,10))

    plots[0].set_title("Train keypoints With Size")
    plots[0].imshow(keypoints_with_size)

    plots[1].set_title("Train keypoints Without Size")
    plots[1].imshow(keypoints_without_size)
    
    print("Number of Keypoints Detected In The Stolen Image: ", len(keypoints))

# %% [markdown]
# ## Running the algorithm
#
# Find keypoints on every image in the database. Display the keypoints with their size (left) and without (right).

# %%
orb_results = []

for index, _ in enumerate(stolen_paintings[0]):

    orb_res = orb.detectAndCompute(stolen_paintings[0][index], None)
    orb_results.append(orb_res)

    sp_keypoints, sp_descriptors = orb_res
    
    #visualize_keypoints(stolen_paintings[1][index], sp_keypoints, scale=100)

# %% [markdown]
# # Searching for a painting in the database

# %%
def search_for_painting(painting_index, draw_match = True):
    
    found_painting = found_paintings[0][painting_index]
    found_painting_rgb = found_paintings[1][painting_index]
    found_painting_keypoints, found_painting_descriptor = orb.detectAndCompute(found_painting, None)

    best_match_index, matches, mask = get_best_match(found_painting_descriptor)
    
    if best_match_index < 0 and draw_match:
        print(f"Sorry, no match found for painting: {painting_index}")
        # TODO - fix imshow
        plt.imshow(found_paintings[1][painting_index])
        return
    
    if draw_match:
        draw_matches(best_match_index, found_painting_rgb, found_painting_keypoints, matches, mask)
    
    return best_match_index

# %% [markdown]
# ## Techniques to improve accuracy

# %% [markdown]
# ### Histogram comparison

# %%
from scipy.spatial import distance as dist

def calculate_histograms(images, bin_size = 32):
    
    hists = [cv2.calcHist([image], [0, 1, 2], None, [bin_size, bin_size, bin_size], [0, 256, 0, 256, 0, 256])
             for image in images]
    
    hists = [cv2.normalize(hist, hist).flatten() for hist in hists]
    
    return hists

# %%
found_paintings_hists = calculate_histograms(found_paintings[1])
stolen_paintings_hists = calculate_histograms(stolen_paintings[1])

# %%
def compare_hists(hist1, hist2):
    
    corr = cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)
    
    return corr

# %% [markdown]
# ## FLANN Based Matcher

# %%
# 1. parametr FlannBasedMatcheru
FLANN_INDEX_LSH = 6
index_params= dict(algorithm = FLANN_INDEX_LSH,
                   table_number = 6, # 12
                   key_size = 12,     # 20
                   multi_probe_level = 1) #2

# %%
# 2. parametr FlannBasedMatcheru
search_params = dict(checks=50)   # or pass empty dictionary

# %%
def get_best_match(found_painting_descriptor, k = 2, min_matches = 10):

    matches_count = {}
    matches_count[-1] = 0
    
    matches = {}
    matches[-1] = None
    
    matches_masks = {}
    matches_masks[-1] = None
    
    
    for index, stolen_res in enumerate(orb_results):
        stolen_keypoints, stolen_descriptor = stolen_res

        # TODO - this was lazy fixed
        if found_painting_descriptor is None or len(found_painting_descriptor) <= k or stolen_descriptor is None or len(stolen_descriptor) <= k:
            best_match_index = -1
            break
        
        # Cross check parametr
        flann = cv2.FlannBasedMatcher(index_params, search_params)

        # Perform the matching between the ORB descriptors of the training image and the test image
        matches[index] = flann.knnMatch(stolen_descriptor, found_painting_descriptor, k)
        # deskriptor = "fingerprint" keypointu, vektor 0 a 1, napr. BRIEF rozmaze misto a z toho spocita vektor
        # ORB muze pouzivat rBRIEF, tzn. pocita i s rotaci obrazu

        ok_matches_num = 0

        # Need to draw only good matches, so create a mask
        matches_masks[index] = [[0,0] for i in range(len(matches[index]))]
        # ratio test as per Lowe's paper
        for i, candidates in enumerate(matches[index]):
            if (len(candidates)<2):
                continue # nedostatek bodu pro porovnani
            m, n = candidates    
            if m.distance < 0.7*n.distance:
                matches_masks[index][i]=[1,0]
                ok_matches_num = ok_matches_num + 1 
        
        matches_count[index] = ok_matches_num
            
        
        # print("Pocet prijatelnych matchu: ", ok_matches_num)
        
    best_match_index = max(matches_count, key=matches_count.get)
    #print(type(best_match_index))
    best_match_index = best_match_index if matches_count[best_match_index] >= min_matches else -1
        
    return best_match_index, matches[best_match_index], matches_masks[best_match_index]

# %%
def draw_matches(stolen_index, found_painting, found_painting_keypoints, matches, matchesMask):
    
    draw_params = dict(matchColor = (0,255,0),
                       singlePointColor = (255,0,0),
                       matchesMask = matchesMask,
                       flags = cv2.DrawMatchesFlags_DEFAULT)

    
    
    result = draw_matches_scaled(found_painting, found_painting_keypoints,
                                 stolen_paintings[1][stolen_index], orb_results[stolen_index][0],
                                 matches, matchesMask, draw_params, 100)
    
    # Display the best matching points
    plt.rcParams['figure.figsize'] = [28.0, 14.0]
    plt.title('Painting found! Best match: ')
    plt.imshow(result)
    plt.show()

# %% [markdown]
# # Testing the algorithm on all the paintings

# %%
total_searched = len(found_paintings[0])
not_found = {}
found_ok = {}
found_wrong = {}

histograms_good_match = []
histograms_bad_match = []

for index in range(0, total_searched):
    best_match_index = search_for_painting(index, draw_match = False)
    
    print(f"Best match for {index} is {best_match_index}")
    
    hist_corr = 0
    if best_match_index is not None:
        hist_corr = compare_hists(found_paintings_hists[index], stolen_paintings_hists[best_match_index])
        print(f"Histogram correlation: {hist_corr}")
    
    if index == best_match_index:
        histograms_good_match.append(hist_corr)
    else:
        histograms_bad_match.append(hist_corr)
    
    if index is None:
        not_found[index] = best_match_index
    elif index == best_match_index:
        found_ok[index] = best_match_index
    elif index != best_match_index:
        found_wrong[index] = best_match_index
# Out:
# Best match for 0 is 0
# Histogram correlation: 0.039568990976050336
# Best match for 1 is 1
# Histogram correlation: 0.7528875159207026
# Best match for 2 is 339
# Histogram correlation: 0.007662684952125709
# Best match for 3 is 284
# Histogram correlation: 0.23658478272786884
# Best match for 4 is 312
# Histogram correlation: 0.0008676106516836554
# Best match for 5 is 285
# Histogram correlation: -0.0011879801035128224
# Best match for 6 is 6
# Histogram correlation: 0.533325176894145
# Best match for 7 is 7
# Histogram correlation: 0.11409113766575715
# Best match for 8 is 8
# Histogram correlation: 0.7321931900255695
# Best match for 9 is 9
# Histogram correlation: 0.6516108677414055
# Best match for 10 is 221
# Histogram correlation: 0.4994769345134565
# Best match for 11 is 11
# Histogram correlation: 0.0007186062276602036
# Best match for 12 is 346
# Histogram correlation: -0.002261388218274785
# Best match for 13 is 314
# Histogram correlation: 0.06515690201106426
# Best match for 14 is 14
# Histogram correlation: 0.6304667873941563
# Best match for 15 is -1
# Histogram correlation: 0.0003858726365472992
# Best match for 16 is 16
# Histogram correlation: 0.15280479932628968
# Best match for 17 is -1
# Histogram correlation: 0.01901923464491688
# Best match for 18 is 18
# Histogram correlation: 0.29068285842994945
# Best match for 19 is 19
# Histogram correlation: 0.8369020489684746
# Best match for 20 is 20
# Histogram correlation: 0.3708574836765968
# Best match for 21 is 145
# Histogram correlation: 0.06407995879532606
# Best match for 22 is 22
# Histogram correlation: 0.5344752757310743
# Best match for 23 is 33
# Histogram correlation: 0.003953470389919469
# Best match for 24 is 339
# Histogram correlation: 0.14053767010590326
# Best match for 25 is 25
# Histogram correlation: 0.861379833744122
# Best match for 26 is 26
# Histogram correlation: 0.12276711399219833
# Best match for 27 is 352
# Histogram correlation: -0.0016262576201761692
# Best match for 28 is 28
# Histogram correlation: 5.6881398274278316e-05
# Best match for 29 is 163
# Histogram correlation: 0.059134765046376866
# Best match for 30 is 1
# Histogram correlation: 0.0894334437474625
# Best match for 31 is 339
# Histogram correlation: 8.348189648806577e-05
# Best match for 32 is 361
# Histogram correlation: 0.009253124650461143
# Best match for 33 is 312
# Histogram correlation: 0.0001235693493311649
# Best match for 34 is 172
# Histogram correlation: 0.05457081372749632
# Best match for 35 is 78
# Histogram correlation: 0.05137994997851595
# Best match for 36 is 259
# Histogram correlation: 0.1553766973605514
# Best match for 37 is 353
# Histogram correlation: 0.0791717719425498
# Best match for 38 is 389
# Histogram correlation: 0.1493607040536848
# Best match for 39 is 301
# Histogram correlation: 0.14737401275752446
# Best match for 40 is 40
# Histogram correlation: 0.8893975914865132
# Best match for 41 is 41
# Histogram correlation: 0.8574709029686702
# Best match for 42 is 42
# Histogram correlation: 0.36768869406115506
# Best match for 43 is 43
# Histogram correlation: 0.3496942637747387
# Best match for 44 is 44
# Histogram correlation: 0.9192545404032938
# Best match for 45 is 388
# Histogram correlation: 8.375077650435501e-05
# Best match for 46 is 46
# Histogram correlation: 0.0647073086119485
# Best match for 47 is 47
# Histogram correlation: 0.01669160827906323
# Best match for 48 is 19
# Histogram correlation: 0.1518983462285926
# Best match for 49 is 4
# Histogram correlation: 0.005287091849976098
# Best match for 50 is 3
# Histogram correlation: 0.4177530100260077
# Best match for 51 is 220
# Histogram correlation: 0.09972081491172483
# Best match for 52 is 52
# Histogram correlation: 0.027485462988237914
# Best match for 53 is 53
# Histogram correlation: 0.03567393434484287
# Best match for 54 is 390
# Histogram correlation: 0.022558776594235656
# Best match for 55 is 55
# Histogram correlation: 0.0035573518939333755
# Best match for 56 is 56
# Histogram correlation: 0.042669975300926484
# Best match for 57 is 57
# Histogram correlation: 0.031883634646071635
# Best match for 58 is 58
# Histogram correlation: 0.2078229906267453
# Best match for 59 is 59
# Histogram correlation: 0.7223297646663633
# Best match for 60 is 60
# Histogram correlation: 0.5556449179126723
# Best match for 61 is 4
# Histogram correlation: 0.006636534578047438
# Best match for 62 is 366
# Histogram correlation: 0.003752936400530767
# Best match for 63 is 339
# Histogram correlation: 0.0002485081789078997
# Best match for 64 is 117
# Histogram correlation: 0.17383558833580764
# Best match for 65 is 335
# Histogram correlation: 0.10927753789106796
# Best match for 66 is 4
# Histogram correlation: 0.01589994293745077
# Best match for 67 is 67
# Histogram correlation: 0.7724469576837967
# Best match for 68 is -1
# Histogram correlation: 0.11305050743648254
# Best match for 69 is 348
# Histogram correlation: 0.3674712890567031
# Best match for 70 is 238
# Histogram correlation: 0.3234163481603412
# Best match for 71 is 254
# Histogram correlation: 0.011251665657555606
# Best match for 72 is 72
# Histogram correlation: 0.44556723594417263
# Best match for 73 is -1
# Histogram correlation: 0.016372181919272217
# Best match for 74 is 139
# Histogram correlation: 0.05685554985681485
# Best match for 75 is 194
# Histogram correlation: 0.009586108101552264
# Best match for 76 is 76
# Histogram correlation: 0.3949245757399139
# Best match for 77 is 77
# Histogram correlation: 0.20988927742474955
# Best match for 78 is 78
# Histogram correlation: 0.6869263722163319
# Best match for 79 is 389
# Histogram correlation: 0.07271240889051886
# Best match for 80 is 339
# Histogram correlation: 0.0003542024975399054
# Best match for 81 is 81
# Histogram correlation: 0.3607925500553798
# Best match for 82 is 82
# Histogram correlation: 0.022721597181688258
# Best match for 83 is 83
# Histogram correlation: 0.33764038547147834
# Best match for 84 is 84
# Histogram correlation: 0.5491613057995192
# Best match for 85 is 172
# Histogram correlation: -0.00018911320210700808
# Best match for 86 is 276
# Histogram correlation: -0.00021702377359489634
# Best match for 87 is 3
# Histogram correlation: 0.01129801252755719
# Best match for 88 is 41
# Histogram correlation: 0.09891285674965596
# Best match for 89 is 275
# Histogram correlation: 0.039437660258070655
# Best match for 90 is 90
# Histogram correlation: 0.06078930054042243
# Best match for 91 is 235
# Histogram correlation: 0.03345159351669618
# Best match for 92 is 32
# Histogram correlation: 0.3069558267665438
# Best match for 93 is 198
# Histogram correlation: -0.000528318987368327
# Best match for 94 is 94
# Histogram correlation: 0.02020452625740413
# Best match for 95 is 312
# Histogram correlation: 0.003712005471587312
# Best match for 96 is 96
# Histogram correlation: 0.0008205061601471995
# Best match for 97 is 97
# Histogram correlation: 0.04641822058458904
# Best match for 98 is 98
# Histogram correlation: 0.2619455159420951
# Best match for 99 is 312
# Histogram correlation: -4.284074708658435e-05
# Best match for 100 is 209
# Histogram correlation: 0.0002766107308003235
# Best match for 101 is 101
# Histogram correlation: 0.042395787669715405
# Best match for 102 is 102
# Histogram correlation: 0.42796553763090533
# Best match for 103 is 103
# Histogram correlation: 0.45138709990394266
# Best match for 104 is 104
# Histogram correlation: 0.7356349913816397
# Best match for 105 is 105
# Histogram correlation: 0.8284185070649012
# Best match for 106 is 106
# Histogram correlation: 0.0708661303097108
# Best match for 107 is 339
# Histogram correlation: 0.001914758566219294
# Best match for 108 is 404
# Histogram correlation: 0.000733222232174177
# Best match for 109 is 109
# Histogram correlation: 0.2113174234157353
# Best match for 110 is 110
# Histogram correlation: 0.498173532035544
# Best match for 111 is 111
# Histogram correlation: 0.2766365785912848
# Best match for 112 is 205
# Histogram correlation: -0.00026373850010309236
# Best match for 113 is 238
# Histogram correlation: 0.3092569782600634
# Best match for 114 is 114
# Histogram correlation: 0.006804830869051093
# Best match for 115 is 404
# Histogram correlation: 0.044101865791172735
# Best match for 116 is 116
# Histogram correlation: 0.8500619488350792
# Best match for 117 is 117
# Histogram correlation: 0.17583907525434872
# Best match for 118 is 312
# Histogram correlation: 0.00040949358658235634
# Best match for 119 is 339
# Histogram correlation: 0.0001007628927722037
# Best match for 120 is 238
# Histogram correlation: 0.10637581822562774
# Best match for 121 is 89
# Histogram correlation: 0.0721440420744795
# Best match for 122 is 4
# Histogram correlation: 0.016262352962914232
# Best match for 123 is 374
# Histogram correlation: 0.0709558230625793
# Best match for 124 is -1
# Histogram correlation: -4.217711165165961e-05
# Best match for 125 is 125
# Histogram correlation: 0.0005138709064525826
# Best match for 126 is 4
# Histogram correlation: 0.05071245868487772
# Best match for 127 is 173
# Histogram correlation: 0.05790342035880846
# Best match for 128 is 128
# Histogram correlation: 0.694243709288739
# Best match for 129 is 339
# Histogram correlation: 7.905593008057683e-05
# Best match for 130 is 130
# Histogram correlation: 0.031055974377804458
# Best match for 131 is 131
# Histogram correlation: 0.12355870220090387
# Best match for 132 is 112
# Histogram correlation: 0.024420709574869304
# Best match for 133 is 39
# Histogram correlation: 0.2857824887271495
# Best match for 134 is -1
# Histogram correlation: 0.005002672666585733
# Best match for 135 is 249
# Histogram correlation: 0.17042482395534644
# Best match for 136 is 136
# Histogram correlation: 0.015512912958528241
# Best match for 137 is 137
# Histogram correlation: 0.01191626918774119
# Best match for 138 is 241
# Histogram correlation: 0.0103578496472543
# Best match for 139 is 139
# Histogram correlation: 0.6100864204120576
# Best match for 140 is 240
# Histogram correlation: 0.0006858211468396418
# Best match for 141 is -1
# Histogram correlation: 0.0023501710170691866
# Best match for 142 is 142
# Histogram correlation: 0.3141219490933624
# Best match for 143 is 143
# Histogram correlation: 0.06990169826863697
# Best match for 144 is 144
# Histogram correlation: 0.03840445477321367
# Best match for 145 is 145
# Histogram correlation: 0.8794087891477443
# Best match for 146 is 146
# Histogram correlation: 0.578478126493713
# Best match for 147 is 147
# Histogram correlation: 0.11385501643556113
# Best match for 148 is 39
# Histogram correlation: 0.041504848214264034
# Best match for 149 is 125
# Histogram correlation: 0.0004862053989932372
# Best match for 150 is 312
# Histogram correlation: 0.00290128246183284
# Best match for 151 is 151
# Histogram correlation: 0.002999620138751982
# Best match for 152 is 256
# Histogram correlation: 0.0001425681789291526
# Best match for 153 is 100
# Histogram correlation: -0.0002237302320110546
# Best match for 154 is 208
# Histogram correlation: -0.0011951217233122815
# Best match for 155 is 155
# Histogram correlation: 0.908573246434212
# Best match for 156 is 156
# Histogram correlation: 0.09847745032682842
# Best match for 157 is 33
# Histogram correlation: -0.0002183616774632484
# Best match for 158 is 78
# Histogram correlation: 0.0024278572818557287
# Best match for 159 is 159
# Histogram correlation: 0.3803853416516723
# Best match for 160 is 185
# Histogram correlation: 0.22738586753371834
# Best match for 161 is 268
# Histogram correlation: 0.10074960956560891
# Best match for 162 is 162
# Histogram correlation: 0.9375919030475895
# Best match for 163 is 163
# Histogram correlation: 0.7998493534921643
# Best match for 164 is 197
# Histogram correlation: 0.042614379856777
# Best match for 165 is 165
# Histogram correlation: 0.007352068218297797
# Best match for 166 is 166
# Histogram correlation: 0.6935603516731236
# Best match for 167 is 312
# Histogram correlation: -0.00022494180543421164
# Best match for 168 is 168
# Histogram correlation: 0.7370444354186027
# Best match for 169 is 169
# Histogram correlation: 0.06614565388701375
# Best match for 170 is 394
# Histogram correlation: -0.000782292159626425
# Best match for 171 is 2
# Histogram correlation: 0.05155380836044672
# Best match for 172 is 4
# Histogram correlation: 0.012108343435538972
# Best match for 173 is 173
# Histogram correlation: 0.3852368018690668
# Best match for 174 is 218
# Histogram correlation: 0.17971406264384224
# Best match for 175 is 175
# Histogram correlation: 0.08829751584664554
# Best match for 176 is 383
# Histogram correlation: 0.12406825304978077
# Best match for 177 is 18
# Histogram correlation: -0.00012004746556408433
# Best match for 178 is 4
# Histogram correlation: 0.0041442352295084535
# Best match for 179 is 179
# Histogram correlation: 0.03527674663633994
# Best match for 180 is 180
# Histogram correlation: 0.1800785633964455
# Best match for 181 is 181
# Histogram correlation: 0.6367275414096066
# Best match for 182 is 217
# Histogram correlation: 0.05559411232567339
# Best match for 183 is 183
# Histogram correlation: 0.02634445261769252
# Best match for 184 is 184
# Histogram correlation: 0.24023859725684663
# Best match for 185 is 211
# Histogram correlation: 0.23657518691785803
# Best match for 186 is -1
# Histogram correlation: -0.00012629817404495968
# Best match for 187 is 138
# Histogram correlation: 0.11460709204948727
# Best match for 188 is 188
# Histogram correlation: 0.3585248380850406
# Best match for 189 is 154
# Histogram correlation: 0.008677232542181997
# Best match for 190 is 190
# Histogram correlation: 0.6097504055012064
# Best match for 191 is 399
# Histogram correlation: 0.1769824867603171
# Best match for 192 is 192
# Histogram correlation: 0.12800337354626956
# Best match for 193 is 193
# Histogram correlation: 0.002775951964827298
# Best match for 194 is -1
# Histogram correlation: 0.02748623644239912
# Best match for 195 is 157
# Histogram correlation: 0.6219709038321006
# Best match for 196 is 39
# Histogram correlation: 0.017289501843657466
# Best match for 197 is 197
# Histogram correlation: 0.4234083336173794
# Best match for 198 is 224
# Histogram correlation: 0.0011355084624263658
# Best match for 199 is 199
# Histogram correlation: 0.8395724016711992
# Best match for 200 is 293
# Histogram correlation: 0.05376030387953349
# Best match for 201 is 364
# Histogram correlation: 0.2205635508663888
# Best match for 202 is 202
# Histogram correlation: 0.2137079832136969
# Best match for 203 is -1
# Histogram correlation: 0.025543921244307974
# Best match for 204 is 204
# Histogram correlation: 0.47265285012485303
# Best match for 205 is 205
# Histogram correlation: 0.03493362212436473
# Best match for 206 is 206
# Histogram correlation: 0.007917104476964143
# Best match for 207 is 4
# Histogram correlation: 0.0067534223355042115
# Best match for 208 is 232
# Histogram correlation: 0.11283352110620051
# Best match for 209 is 209
# Histogram correlation: 0.011661100819089625
# Best match for 210 is 273
# Histogram correlation: -0.0019118279027547222
# Best match for 211 is 211
# Histogram correlation: 0.8627431369447291
# Best match for 212 is 362
# Histogram correlation: 0.055601004576422634
# Best match for 213 is 213
# Histogram correlation: 0.2526311791634468
# Best match for 214 is 167
# Histogram correlation: 0.008136754539666061
# Best match for 215 is 165
# Histogram correlation: 0.05904065150259692
# Best match for 216 is 322
# Histogram correlation: 0.02315845286395015
# Best match for 217 is 331
# Histogram correlation: 0.041682292429356435
# Best match for 218 is 218
# Histogram correlation: 0.13740951824842385
# Best match for 219 is 136
# Histogram correlation: 0.008756670996736906
# Best match for 220 is 220
# Histogram correlation: 0.2417477550517157
# Best match for 221 is 221
# Histogram correlation: 0.4659654964431477
# Best match for 222 is 261
# Histogram correlation: 0.008411185823423303
# Best match for 223 is 19
# Histogram correlation: 0.007203233025107887
# Best match for 224 is 172
# Histogram correlation: 0.051672816280148776
# Best match for 225 is 225
# Histogram correlation: 0.4906262762800082
# Best match for 226 is 388
# Histogram correlation: 0.005669852343265873
# Best match for 227 is 227
# Histogram correlation: 0.0029481665087796125
# Best match for 228 is 341
# Histogram correlation: 0.019981028012706726
# Best match for 229 is 229
# Histogram correlation: 0.03755439448431099
# Best match for 230 is 3
# Histogram correlation: 0.015840624574934455
# Best match for 231 is 231
# Histogram correlation: 0.33727652864367874
# Best match for 232 is 232
# Histogram correlation: 0.5609765051797782
# Best match for 233 is 342
# Histogram correlation: 0.01998562542805871
# Best match for 234 is 234
# Histogram correlation: 0.712292939388915
# Best match for 235 is 136
# Histogram correlation: 0.02696937554592701
# Best match for 236 is 236
# Histogram correlation: 0.5141163292797518
# Best match for 237 is 237
# Histogram correlation: 0.14478723762874043
# Best match for 238 is 238
# Histogram correlation: 0.662898887424824
# Best match for 239 is -1
# Histogram correlation: -0.00021167746113679532
# Best match for 240 is 383
# Histogram correlation: 0.2660007370164306
# Best match for 241 is 236
# Histogram correlation: 0.05660012389501819
# Best match for 242 is 71
# Histogram correlation: 0.0026838299354426977
# Best match for 243 is -1
# Histogram correlation: 0.02732603752957438
# Best match for 244 is 244
# Histogram correlation: 0.4659140549590757
# Best match for 245 is 245
# Histogram correlation: 0.22379967857565003
# Best match for 246 is 388
# Histogram correlation: 0.0029694342615080526
# Best match for 247 is 247
# Histogram correlation: 0.504464416152261
# Best match for 248 is 371
# Histogram correlation: 0.15374194566625587
# Best match for 249 is 249
# Histogram correlation: 0.9721129017481303
# Best match for 250 is 250
# Histogram correlation: 0.22404651340700915
# Best match for 251 is 312
# Histogram correlation: -0.00022624512193439173
# Best match for 252 is 270
# Histogram correlation: 0.03946428259248494
# Best match for 253 is -1
# Histogram correlation: 0.04889765818778967
# Best match for 254 is -1
# Histogram correlation: 0.008403189063286642
# Best match for 255 is 386
# Histogram correlation: 0.0315269397652898
# Best match for 256 is 4
# Histogram correlation: 0.04091224124564766
# Best match for 257 is 257
# Histogram correlation: 0.9141845091326154
# Best match for 258 is 258
# Histogram correlation: 0.8091304100364027
# Best match for 259 is 259
# Histogram correlation: 0.8580599744346223
# Best match for 260 is 306
# Histogram correlation: 0.010135802349314528
# Best match for 261 is 261
# Histogram correlation: 0.26495577749874555
# Best match for 262 is -1
# Histogram correlation: 0.015067159482532668
# Best match for 263 is 312
# Histogram correlation: 0.0072053900324861465
# Best match for 264 is 264
# Histogram correlation: 0.4330280916902294
# Best match for 265 is 265
# Histogram correlation: 0.8050926277236486
# Best match for 266 is 232
# Histogram correlation: 0.04430824406977599
# Best match for 267 is 267
# Histogram correlation: 0.8090368456421814
# Best match for 268 is 346
# Histogram correlation: 0.046471597470817576
# Best match for 269 is 269
# Histogram correlation: 0.7227502211897805
# Best match for 270 is -1
# Histogram correlation: 0.009298696580981886
# Best match for 271 is 271
# Histogram correlation: 0.5026119084973886
# Best match for 272 is 221
# Histogram correlation: 0.8349840590070471
# Best match for 273 is 273
# Histogram correlation: 0.006820448240949173
# Best match for 274 is 386
# Histogram correlation: 0.06914274256596406
# Best match for 275 is 275
# Histogram correlation: 0.2541738077048116
# Best match for 276 is 276
# Histogram correlation: 0.76376896057268
# Best match for 277 is 277
# Histogram correlation: 0.6055082454603147
# Best match for 278 is 278
# Histogram correlation: 0.48990580354154667
# Best match for 279 is 116
# Histogram correlation: 0.05508698216973765
# Best match for 280 is 312
# Histogram correlation: 0.015148194164000112
# Best match for 281 is 281
# Histogram correlation: 0.07558915767020215
# Best match for 282 is 137
# Histogram correlation: 0.04280012128199586
# Best match for 283 is 298
# Histogram correlation: 0.03794772454369608
# Best match for 284 is 284
# Histogram correlation: 0.1582709546641925
# Best match for 285 is 32
# Histogram correlation: -0.002626153146114038
# Best match for 286 is 346
# Histogram correlation: 0.01795807989377929
# Best match for 287 is 197
# Histogram correlation: 0.0002838839526022739
# Best match for 288 is 312
# Histogram correlation: 0.008979935789513475
# Best match for 289 is 39
# Histogram correlation: 0.034957537839671364
# Best match for 290 is 290
# Histogram correlation: 0.7372841875995041
# Best match for 291 is 291
# Histogram correlation: 0.45614216672805186
# Best match for 292 is 292
# Histogram correlation: 0.04276898292196762
# Best match for 293 is 293
# Histogram correlation: 0.09517723807203969
# Best match for 294 is 294
# Histogram correlation: 0.8527279046976893
# Best match for 295 is -1
# Histogram correlation: 0.0231258236597719
# Best match for 296 is 221
# Histogram correlation: 0.5439774213667631
# Best match for 297 is 175
# Histogram correlation: 0.0036751485273423274
# Best match for 298 is 298
# Histogram correlation: 0.20049914246522296
# Best match for 299 is 221
# Histogram correlation: 0.32232811816193296
# Best match for 300 is 300
# Histogram correlation: 0.3262303261039115
# Best match for 301 is 301
# Histogram correlation: 0.11287212663457366
# Best match for 302 is 164
# Histogram correlation: 0.016732521197361308
# Best match for 303 is 4
# Histogram correlation: -0.0005174485503934394
# Best match for 304 is 372
# Histogram correlation: -0.0005508559014130766
# Best match for 305 is 305
# Histogram correlation: 0.0018801780086089676
# Best match for 306 is 306
# Histogram correlation: 0.26005413208367484
# Best match for 307 is 244
# Histogram correlation: -0.0003152245259548515
# Best match for 308 is 308
# Histogram correlation: 0.8225509696500382
# Best match for 309 is 137
# Histogram correlation: 0.01330081093130014
# Best match for 310 is 390
# Histogram correlation: 0.010717888694519003
# Best match for 311 is 311
# Histogram correlation: 0.31641996284734397
# Best match for 312 is 312
# Histogram correlation: 0.9767196984873942
# Best match for 313 is 32
# Histogram correlation: 0.08976795355963164
# Best match for 314 is 314
# Histogram correlation: 0.613214939094203
# Best match for 315 is 285
# Histogram correlation: 0.059426732558781524
# Best match for 316 is 350
# Histogram correlation: -0.00014988274752593845
# Best match for 317 is 127
# Histogram correlation: -0.0008941710502615941
# Best match for 318 is 318
# Histogram correlation: 0.20384705896428273
# Best match for 319 is 224
# Histogram correlation: -0.0026889948123043606
# Best match for 320 is 19
# Histogram correlation: 0.05465784664390573
# Best match for 321 is 321
# Histogram correlation: 0.5993789923504573
# Best match for 322 is 322
# Histogram correlation: 0.83326788857596
# Best match for 323 is 323
# Histogram correlation: 0.747027989629635
# Best match for 324 is 4
# Histogram correlation: 0.0002998958752458882
# Best match for 325 is 325
# Histogram correlation: 0.14128389292475946
# Best match for 326 is 326
# Histogram correlation: 0.15215482383238857
# Best match for 327 is 140
# Histogram correlation: 0.06681915752426947
# Best match for 328 is 350
# Histogram correlation: 0.015992950050975036
# Best match for 329 is 3
# Histogram correlation: 0.0009053580141688247
# Best match for 330 is 16
# Histogram correlation: -0.00027598239869345664
# Best match for 331 is 331
# Histogram correlation: 0.8461876752196296
# Best match for 332 is 306
# Histogram correlation: -0.0013156967130380295
# Best match for 333 is 333
# Histogram correlation: 0.15123664953075266
# Best match for 334 is 241
# Histogram correlation: 0.028347149636454686
# Best match for 335 is 335
# Histogram correlation: 0.4353468683815144
# Best match for 336 is 336
# Histogram correlation: 0.9815389014146664
# Best match for 337 is 337
# Histogram correlation: 0.4652718793690242
# Best match for 338 is 338
# Histogram correlation: 0.6117323414988382
# Best match for 339 is 339
# Histogram correlation: 0.05946799338608432
# Best match for 340 is 340
# Histogram correlation: 0.19815771471053076
# Best match for 341 is 341
# Histogram correlation: 0.1461495645073463
# Best match for 342 is 342
# Histogram correlation: 0.4308895677806482
# Best match for 343 is 343
# Histogram correlation: 0.5601412185325648
# Best match for 344 is 77
# Histogram correlation: 0.07638391568670223
# Best match for 345 is 345
# Histogram correlation: 0.9004782176688129
# Best match for 346 is 345
# Histogram correlation: 0.3857369385131804
# Best match for 347 is -1
# Histogram correlation: 0.002612744496927354
# Best match for 348 is 71
# Histogram correlation: 0.008078975740107264
# Best match for 349 is -1
# Histogram correlation: 0.004272335191828556
# Best match for 350 is 312
# Histogram correlation: 0.00034018075086888745
# Best match for 351 is 312
# Histogram correlation: 0.0033235680046785885
# Best match for 352 is 352
# Histogram correlation: 0.114656320006553
# Best match for 353 is 17
# Histogram correlation: 0.09819710333970444
# Best match for 354 is 354
# Histogram correlation: 0.8757600311054031
# Best match for 355 is 119
# Histogram correlation: -0.0007556130132577693
# Best match for 356 is 356
# Histogram correlation: 0.07509157328721007
# Best match for 357 is 357
# Histogram correlation: 0.17431955289028253
# Best match for 358 is 184
# Histogram correlation: 0.6190331399848632
# Best match for 359 is 24
# Histogram correlation: 0.341957029242277
# Best match for 360 is -1
# Histogram correlation: 0.18772120278277243
# Best match for 361 is 361
# Histogram correlation: 0.16153696102782567
# Best match for 362 is 100
# Histogram correlation: 0.004408439312112982
# Best match for 363 is 19
# Histogram correlation: 0.025511948438806234
# Best match for 364 is 364
# Histogram correlation: 0.5609844497812833
# Best match for 365 is 322
# Histogram correlation: 0.00023133848197310274
# Best match for 366 is 386
# Histogram correlation: 0.17535783137183553
# Best match for 367 is 367
# Histogram correlation: 0.011303181259366874
# Best match for 368 is 368
# Histogram correlation: 0.692721567209443
# Best match for 369 is 214
# Histogram correlation: 0.013873991525045665
# Best match for 370 is 154
# Histogram correlation: 0.21451558926113448
# Best match for 371 is 329
# Histogram correlation: 0.30620635538279883
# Best match for 372 is 117
# Histogram correlation: -0.0004747700086767284
# Best match for 373 is 373
# Histogram correlation: 0.5760934461466289
# Best match for 374 is 184
# Histogram correlation: 0.8207813991561763
# Best match for 375 is 339
# Histogram correlation: 0.013455091384512867
# Best match for 376 is -1
# Histogram correlation: 0.0052937296946317615
# Best match for 377 is -1
# Histogram correlation: -0.0016488175078188591
# Best match for 378 is 378
# Histogram correlation: 0.6926965670034922
# Best match for 379 is 228
# Histogram correlation: 0.0068988365144153985
# Best match for 380 is 380
# Histogram correlation: 0.47571255712709104
# Best match for 381 is 193
# Histogram correlation: 0.0004853487726126468
# Best match for 382 is 190
# Histogram correlation: 0.5991244684657742
# Best match for 383 is -1
# Histogram correlation: 0.009717006552804752
# Best match for 384 is 160
# Histogram correlation: 0.05225795514225218
# Best match for 385 is 157
# Histogram correlation: 0.7120550460108821
# Best match for 386 is 374
# Histogram correlation: 0.31468985235010427
# Best match for 387 is 43
# Histogram correlation: 0.07202391095424988
# Best match for 388 is 3
# Histogram correlation: 0.09966496314837062
# Best match for 389 is -1
# Histogram correlation: 0.019449399680112323
# Best match for 390 is 390
# Histogram correlation: 0.3128237846779303
# Best match for 391 is 371
# Histogram correlation: 0.0065434128346287986
# Best match for 392 is 392
# Histogram correlation: 0.6308794999406102
# Best match for 393 is 378
# Histogram correlation: 0.0862206114342963
# Best match for 394 is 394
# Histogram correlation: 0.12002763121930522
# Best match for 395 is 179
# Histogram correlation: 0.015581196916855458
# Best match for 396 is 396
# Histogram correlation: 0.3122113383708328
# Best match for 397 is 397
# Histogram correlation: 0.06582113549638151
# Best match for 398 is 235
# Histogram correlation: 0.09383888770949719
# Best match for 399 is 399
# Histogram correlation: 0.37712775823235845
# Best match for 400 is 400
# Histogram correlation: 0.18047071227751246
# Best match for 401 is 401
# Histogram correlation: 0.09848941366876487
# Best match for 402 is 293
# Histogram correlation: 0.006885362073335838
# Best match for 403 is 403
# Histogram correlation: 0.5301625086779638
# Best match for 404 is 404
# Histogram correlation: 0.055881593578622615
# Best match for 405 is 389
# Histogram correlation: 0.0014867171723626166
# Best match for 406 is -1
# Histogram correlation: -0.00021620688754623034
# Best match for 407 is 19
# Histogram correlation: 0.06989117543915234
# Best match for 408 is 184
# Histogram correlation: 0.1992549521505246
# Best match for 409 is 344
# Histogram correlation: 0.09639608782318497
# Best match for 410 is 206
# Histogram correlation: 0.04135427110936602
# Best match for 411 is 95
# Histogram correlation: 0.011534683433404554
# Best match for 412 is 240
# Histogram correlation: 0.10265042957894378
# Best match for 413 is 346
# Histogram correlation: 0.02570831351269046
# Best match for 414 is 343
# Histogram correlation: 0.06922084455402139
# Best match for 415 is 173
# Histogram correlation: 0.23577014589843334
# Best match for 416 is 3
# Histogram correlation: 0.009008600031780969
# Best match for 417 is 77
# Histogram correlation: 0.008535645907189561
# Best match for 418 is -1
# Histogram correlation: 0.03597502426118687
# Best match for 419 is -1
# Histogram correlation: 0.00012588578695829785
# Best match for 420 is 342
# Histogram correlation: -0.0006286397274867534
# Best match for 421 is 4
# Histogram correlation: 0.013403829277912978
# Best match for 422 is -1
# Histogram correlation: 0.006240097497338331
# Best match for 423 is 162
# Histogram correlation: 0.6421286780969577
# Best match for 424 is 352
# Histogram correlation: 0.029993873945109578
# Best match for 425 is 312
# Histogram correlation: 0.03869768772217852
# Best match for 426 is 87
# Histogram correlation: 0.3369126760899194
# Best match for 427 is 366
# Histogram correlation: 0.016829654833359627
# Best match for 428 is 321
# Histogram correlation: 0.025928543795990622
# Best match for 429 is 260
# Histogram correlation: 0.03381860863245665
# Best match for 430 is 4
# Histogram correlation: 0.0006844888977785283
# Best match for 431 is 362
# Histogram correlation: 0.0017102026221965435
# Best match for 432 is 300
# Histogram correlation: 0.08510602568864167
# Best match for 433 is 403
# Histogram correlation: 0.3987890160332894
# Best match for 434 is 325
# Histogram correlation: 0.027219348261198775
# Best match for 435 is 208
# Histogram correlation: -0.00018974013612349413
# Best match for 436 is 194
# Histogram correlation: 0.05496226122839612
# Best match for 437 is 13
# Histogram correlation: 0.022092351089771523
# Best match for 438 is 19
# Histogram correlation: 0.35008110744686266
# Best match for 439 is 284
# Histogram correlation: 0.7095244080135444
# Best match for 440 is 350
# Histogram correlation: 0.00031129748246044387
# Best match for 441 is 194
# Histogram correlation: 0.17684724655025966
# Best match for 442 is 199
# Histogram correlation: 0.001542450614494524
# Best match for 443 is 291
# Histogram correlation: 0.1486188276410565
# Best match for 444 is 362
# Histogram correlation: 0.041410186931414544
# Best match for 445 is 127
# Histogram correlation: -0.0005137244410291416
# Best match for 446 is 39
# Histogram correlation: 0.011847433687030947
# Best match for 447 is 184
# Histogram correlation: 0.24823599303061117
# Best match for 448 is 281
# Histogram correlation: 0.018939333468768197
# Best match for 449 is 173
# Histogram correlation: 0.06435392858755573
# Best match for 450 is 171
# Histogram correlation: -0.00037898304876988196
# Best match for 451 is 403
# Histogram correlation: 0.29744516981562463
# Best match for 452 is 205
# Histogram correlation: 0.006715765293465901
# Best match for 453 is -1
# Histogram correlation: 0.010469966208437645
# Best match for 454 is 350
# Histogram correlation: 0.1468406018815801
# Best match for 455 is 53
# Histogram correlation: 0.004793115345845936
# Best match for 456 is 221
# Histogram correlation: 0.6126836147775829
# Best match for 457 is 244
# Histogram correlation: -0.0009775791513075146
# Best match for 458 is 119
# Histogram correlation: 0.0006855418491927185
# Best match for 459 is 339
# Histogram correlation: 0.0009210352113473695
# Best match for 460 is 190
# Histogram correlation: 0.2444589327854307
# Best match for 461 is -1
# Histogram correlation: 0.0006133442787619543
# Best match for 462 is 71
# Histogram correlation: 0.07107308716618876
# Best match for 463 is 43
# Histogram correlation: 0.07268634281927008
# Best match for 464 is 390
# Histogram correlation: 0.0017723985561231474
# Best match for 465 is 172
# Histogram correlation: -0.0004199118986278428
# Best match for 466 is 338
# Histogram correlation: 0.07446254235735043
# Best match for 467 is 89
# Histogram correlation: 0.0647384811993215
# Best match for 468 is -1
# Histogram correlation: 3.826676473592003e-05
# Best match for 469 is 3
# Histogram correlation: 0.01971125054443337
# Best match for 470 is -1
# Histogram correlation: 0.0003612724301075987
# Best match for 471 is 100
# Histogram correlation: -4.53928194807197e-05
# Best match for 472 is 154
# Histogram correlation: 0.17710007619560386
# Best match for 473 is 371
# Histogram correlation: 0.011281997906909699
# Best match for 474 is 374
# Histogram correlation: 0.05549582095483984
# Best match for 475 is -1
# Histogram correlation: 0.009272282887596793
# Best match for 476 is 383
# Histogram correlation: 0.10654930286682503

# %%
accuracy = len(found_ok) / (len(not_found) + len(found_wrong))
print(f"Accuracy: {accuracy*100} %")
# Out:
# Accuracy: 63.91752577319587 %

# %% [markdown]
# #### Histograms vs ORB analysis
# How correlated were the histograms depending on whether ORB matched them correctly or not?

# %%
import pandas as pd
import numpy as np


#print(hist_good_match)
hists_g = pd.DataFrame(histograms_good_match).rename(columns={0:"Good"})
print(hists_g.describe())

hists_b = pd.DataFrame(histograms_bad_match).rename(columns={0:"Bad"})
print(hists_b.describe())
# Out:
#              Good
# count  186.000000
# mean     0.381348
# std      0.302769
# min      0.000057
# 25%      0.098480
# 50%      0.337458
# 75%      0.630776
# max      0.981539
#               Bad
# count  291.000000
# mean     0.080117
# std      0.144725
# min     -0.002689
# 25%      0.001844
# 50%      0.019449
# 75%      0.075423
# max      0.834984

# %% [markdown]
# ### Visualizing results

# %%
def visualize_image_tuples(index_dict):
    
    for index_searched, index_found in index_dict.items():
        
        fx, plots = plt.subplots(1, 2, figsize=(20,10))
    
        plots[0].set_title("Searched image:")
        plots[0].imshow(found_paintings[1][index_searched])

        plots[1].set_title("Wrongly matched with:")
        plots[1].imshow(stolen_paintings[1][index_found])

# %%
visualize_image_tuples(found_wrong)
# Out:
# <ipython-input-24-ea87fab9a572>:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fx, plots = plt.subplots(1, 2, figsize=(20,10))

# %% [markdown]
# ## Matching nalezeného obrazu s obrazy v DB  pomocí Brute Force Matcher
#
#
# BFMatcher - Obsahuje parametr crossCheck, údajně dobrá alternativa k ratio testu, ale mně nefunguje dobře. Znamená to, že namatchuje pouze body, které jsou si nejpodobnější navzájem, tzn. pro žádný z dvojice neexistuje v druhém obraze lepší match. Pokud ho dám na False, matcher namatchuje všechny body a výsledek je uplně k ničemu. Pokud na true, matcher namatchuje cca polovinu bodů, ale u všech obrazů a je proto taky k ničemu.
#
# Mnohem lépe se mi osvědčila kombinace knnMatch a ratio testu.
#
# **crossCheck se samozřejmě nedá kombinovat s knnMatch ! !**
#
#
#
#
# zdroj: https://docs.opencv.org/master/dc/dc3/tutorial_py_matcher.html

# %%
kbfm = 2

for index, stolen_res in enumerate(orb_results):
    stolen_keypoints, stolen_descriptor = stolen_res

    # Cross check parametr
    bf = cv2.BFMatcher(cv2.NORM_HAMMING2, crossCheck = False)

        
    
    # Perform the matching between the ORB descriptors of the training image and the test image
    matches = bf.knnMatch(stolen_descriptor, suspect_descriptor, kbfm)
    # deskriptor = "fingerprint" keypointu, vektor 0 a 1, napr. BRIEF rozmaze misto a z toho spocita vektor
    # ORB muze pouzivat rBRIEF, tzn. pocita i s rotaci obrazu
    
   
    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append([m])

    result = cv2.drawMatchesKnn(stolen_paintings[1][index], stolen_keypoints, suspected_painting_rgb, suspect_keypoints, good, None, flags = 2)
    
    # Display the best matching points
    plt.rcParams['figure.figsize'] = [28.0, 14.0]
    plt.title('Best Matching Points')
    plt.imshow(result)
    plt.show()

    # Print total number of matching points between the training and query images
    print("Celkový počet dobrých match (po ratio testu): ", len(good))
